# %%
import labdados

# %%
labdados.ocr(
    arquivos="data/organograma.pdf",
    local=True,
    idiomas="por+eng",
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\Documents\fgv\labdados-sdk\src\labdados\ocr.py:177, in _ocr_local(pdfs, saida_dir, formato, idiomas, dpi, deskew, progress)
#     176 try:
# --> 177     import fitz  # PyMuPDF
#     178     import pytesseract
#
# ModuleNotFoundError: No module named 'fitz'
#
# The above exception was the direct cause of the following exception:
#
# LocalDependencyMissing                    Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 labdados.ocr(
#       2     arquivos="data/organograma.pdf",
#       3     local=True,
#       4     idiomas="por+eng",
#
# File ~\Documents\fgv\labdados-sdk\src\labdados\ocr.py:98, in ocr(arquivos, saida, api_key, modelo, formato, idiomas, dpi, deskew, local, client, progress)
#      95 saida_dir = ensure_output_dir(saida)
#      97 if local:
# ---> 98     return _ocr_local(
# ...

# %%
labdados.ocr(
    arquivos="data/organograma.pdf",
    local=True,
    modelo="paddleocr",
    idiomas="por+eng",
)
