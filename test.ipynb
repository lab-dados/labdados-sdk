# %%
import labdados

labdados.transcricao(
    arquivos="data/audio1119345029.m4a",
    local=True,
    modelo_local="small",   # tiny | base | small | medium | large-v3
    idioma="pt",
    formato="srt",
)

# %%
labdados.ocr(
    arquivos="data/organograma.pdf",
    local=True,
    idiomas="por+eng",
)

# %%
labdados.ocr(
    arquivos="data/organograma.pdf",
    local=True,
    modelo="paddleocr",
    idiomas="por+eng",
)
